# %%
import pandas as pd
df = pd.read_csv('data/kc_house_data.csv')
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %% [markdown]
# From column_names.md
# id - unique identified for a house
# dateDate - house was sold
# pricePrice - is prediction target
# bedroomsNumber - of Bedrooms/House
# bathroomsNumber - of bathrooms/bedrooms
# sqft_livingsquare - footage of the home
# sqft_lotsquare - footage of the lot
# floorsTotal - floors (levels) in house
# waterfront - House which has a view to a waterfront
# view - Has been viewed
# condition - How good the condition is ( Overall )
# grade - overall grade given to the housing unit, based on King County grading system
# sqft_above - square footage of house apart from basement
# sqft_basement - square footage of the basement
# yr_built - Built Year
# yr_renovated - Year when house was renovated
# zipcode - zip
# lat - Latitude coordinate
# long - Longitude coordinate
# sqft_living15 - The square footage of interior housing living space for the nearest 15 neighbors
# sqft_lot15 - The square footage of the land lots of the nearest 15 neighbors

# %% [markdown]
# **Data Cleaning**

# %%
#drop unncecessary from domain knowledge
df.drop(columns= ['date','view','sqft_above','sqft_basement','zipcode','lat','long','sqft_living15','sqft_lot15'],inplace = True)
df.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  condition  grade  yr_built  yr_renovated
# 0         NaN          3      7      1955           0.0
# 1         0.0          3      7      1951        1991.0
# 2         0.0          3      6      1933           NaN
# 3         0.0          5      7      1965           0.0
# 4         0.0          3      8      1987           0.0

# %%
df['total_sqft'] = df['sqft_living'] + df['sqft_lot']
df['age'] = 2024 - df['yr_built']
df.drop(columns= ['yr_built','sqft_living','sqft_lot'],inplace = True)
df.head()
# Out:
#            id     price  bedrooms  bathrooms  floors  waterfront  condition  \
# 0  7129300520  221900.0         3       1.00     1.0         NaN          3
# 1  6414100192  538000.0         3       2.25     2.0         0.0          3
# 2  5631500400  180000.0         2       1.00     1.0         0.0          3
# 3  2487200875  604000.0         4       3.00     1.0         0.0          5
# 4  1954400510  510000.0         3       2.00     1.0         0.0          3
#
#    grade  yr_renovated  total_sqft  age
# 0      7           0.0        6830   69
# 1      7        1991.0        9812   73
# 2      6           NaN       10770   91
# 3      7           0.0        6960   59
# 4      8           0.0        9760   37

# %%
df_yr_renovated = df['yr_renovated'].dropna(inplace= False)

# %%
df_yr_renovated[df_yr_renovated>0]
# Out:
# 1        1991.0
# 35       2002.0
# 95       1991.0
# 103      2010.0
# 125      1992.0
#           ...
# 19602    2004.0
# 20041    2006.0
# 20428    2009.0
# 20431    2014.0
# 20946    2007.0
# Name: yr_renovated, Length: 744, dtype: float64

# %%
df. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            21597 non-null  int64
#  1   price         21597 non-null  float64
#  2   bedrooms      21597 non-null  int64
#  3   bathrooms     21597 non-null  float64
#  4   floors        21597 non-null  float64
#  5   waterfront    19221 non-null  float64
#  6   condition     21597 non-null  int64
#  7   grade         21597 non-null  int64
#  8   yr_renovated  17755 non-null  float64
#  9   total_sqft    21597 non-null  int64
#  10  age           21597 non-null  int64
# dtypes: float64(5), int64(6)
# memory usage: 1.8 MB

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms        floors  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826      1.494096
# std    2.876736e+09  3.673681e+05      0.926299      0.768984      0.539683
# min    1.000102e+06  7.800000e+04      1.000000      0.500000      1.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000      1.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000      1.500000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000      2.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000      3.500000
#
#          waterfront     condition         grade  yr_renovated    total_sqft  \
# count  19221.000000  21597.000000  21597.000000  17755.000000  2.159700e+04
# mean       0.007596      3.409825      7.657915     83.636778  1.717973e+04
# ...

# %%
df.isna().sum()
# Out:
# id                 0
# price              0
# bedrooms           0
# bathrooms          0
# floors             0
# waterfront      2376
# condition          0
# grade              0
# yr_renovated    3842
# total_sqft         0
# age                0
# dtype: int64

# %%
# my business problem, does waterfront and renovation affect the price of a house?
#for this I shall drop the columns above first so as to get a model without them first
df['waterfront'][df['waterfront']>0].sample(n=10), df['yr_renovated'][df['yr_renovated']>0].sample(n=10)
# Out:
# (17460    1.0
#  8217     1.0
#  15678    1.0
#  8042     1.0
#  4482     1.0
#  16767    1.0
#  16319    1.0
#  3930     1.0
#  13512    1.0
#  15316    1.0
#  Name: waterfront, dtype: float64,
#  1083     1999.0
#  15873    2014.0
#  12677    1996.0
#  18529    1983.0
#  18707    1989.0
#  1746     1971.0
#  18400    2004.0
#  16840    1985.0
#  14949    1993.0
#  1859     1979.0
#  Name: yr_renovated, dtype: float64)

# %%
df_transformed = df.drop(columns= ['yr_renovated','waterfront'],inplace = False)
df_transformed.head()
# Out:
#            id     price  bedrooms  bathrooms  floors  condition  grade  \
# 0  7129300520  221900.0         3       1.00     1.0          3      7
# 1  6414100192  538000.0         3       2.25     2.0          3      7
# 2  5631500400  180000.0         2       1.00     1.0          3      6
# 3  2487200875  604000.0         4       3.00     1.0          5      7
# 4  1954400510  510000.0         3       2.00     1.0          3      8
#
#    total_sqft  age
# 0        6830   69
# 1        9812   73
# 2       10770   91
# 3        6960   59
# 4        9760   37

# %%
#drop id
df_transformed.drop(columns= ['id'],inplace = True)

# %%
import seaborn as sns
sns.pairplot(data=df_transformed)

# %%
df_transformed.drop_duplicates(inplace= True)
sns.heatmap(df_transformed.corr(),cmap="coolwarm",annot=True)
# Out:
# <AxesSubplot:>

# %%
df_transformed.corr()
# Out:
#                price  bedrooms  bathrooms    floors  condition     grade  \
# price       1.000000  0.308838   0.525936  0.256952   0.036038  0.668078
# bedrooms    0.308838  1.000000   0.514590  0.178172   0.026423  0.356783
# bathrooms   0.525936  0.514590   1.000000  0.502822  -0.126429  0.665892
# floors      0.256952  0.178172   0.502822  1.000000  -0.263965  0.458702
# condition   0.036038  0.026423  -0.126429 -0.263965   1.000000 -0.146780
# grade       0.668078  0.356783   0.665892  0.458702  -0.146780  1.000000
# total_sqft  0.105001  0.045087   0.104722  0.003186  -0.010166  0.131209
# age        -0.054018 -0.155875  -0.507240 -0.488982   0.361416 -0.447754
#
#             total_sqft       age
# price         0.105001 -0.054018
# bedrooms      0.045087 -0.155875
# bathrooms     0.104722 -0.507240
# floors        0.003186 -0.488982
# condition    -0.010166  0.361416
# grade         0.131209 -0.447754
# total_sqft    1.000000 -0.059908
# age          -0.059908  1.000000

# %% [markdown]
# # Feature Selection

# %%
# select most important features
df_transformed = df_transformed[['grade','bathrooms','bedrooms','floors','price']]
df_transformed.head()
# Out:
#    grade  bathrooms  bedrooms  floors     price
# 0      7       1.00         3     1.0  221900.0
# 1      7       2.25         3     2.0  538000.0
# 2      6       1.00         2     1.0  180000.0
# 3      7       3.00         4     1.0  604000.0
# 4      8       2.00         3     1.0  510000.0

# %% [markdown]
# ## Data Cleaning
#
# Checking for outliers

# %%
import matplotlib.pyplot as plt
# Plotting box plots for each column
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_transformed)
plt.title('Box plots of Selected Columns')
plt.xlabel('Features')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Get the Outliers

# %%
# Calculate IQR for selected columns
Q1 = df_transformed.quantile(0.25)
Q3 = df_transformed.quantile(0.75)
IQR = Q3 - Q1

# Define outlier boundaries
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Find outliers
outliers = ((df_transformed < lower_bound) | (df_transformed > upper_bound)).any(axis=1)

# Print indices of outliers
outlier_indices = df_transformed.index[outliers]

# %% [markdown]
# ## Remove the outliers

# %%
# droping all columns with outliers 
df_transformed = df_transformed.drop(outlier_indices)

# %%
df_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18749 entries, 0 to 21596
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   grade      18749 non-null  int64
#  1   bathrooms  18749 non-null  float64
#  2   bedrooms   18749 non-null  int64
#  3   floors     18749 non-null  float64
#  4   price      18749 non-null  float64
# dtypes: float64(3), int64(2)
# memory usage: 878.9 KB

# %%
df_transformed.duplicated().sum()
# Out:
# 4737

# %%
df_transformed.drop_duplicates(inplace= True)

# %%
df_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14012 entries, 0 to 21596
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   grade      14012 non-null  int64
#  1   bathrooms  14012 non-null  float64
#  2   bedrooms   14012 non-null  int64
#  3   floors     14012 non-null  float64
#  4   price      14012 non-null  float64
# dtypes: float64(3), int64(2)
# memory usage: 656.8 KB

# %%
sns.heatmap(df_transformed.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#seems grade and bathrooms have multicollinearity, I shall thefore drop bathrooms altogether
df_transformed.drop(columns=['bathrooms'], inplace = True)

# %%
sns.heatmap(df_transformed.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preparations

# %%
df_transformed
# Out:
#        grade  bedrooms  floors     price
# 0          7         3     1.0  221900.0
# 1          7         3     2.0  538000.0
# 2          6         2     1.0  180000.0
# 3          7         4     1.0  604000.0
# 4          8         3     1.0  510000.0
# ...      ...       ...     ...       ...
# 21588      8         3     3.0  429000.0
# 21589      9         4     2.0  610685.0
# 21592      8         3     3.0  360000.0
# 21594      7         2     2.0  402101.0
# 21596      7         2     2.0  325000.0
#
# [14012 rows x 4 columns]

# %%
df_transformed
# start with the grade only
x = df_transformed[['grade',  'bedrooms']]
x.head()
# Out:
#    grade  bedrooms
# 0      7         3
# 1      7         3
# 2      6         2
# 3      7         4
# 4      8         3

# %%
y = df_transformed['price']
y.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %% [markdown]
# ### Test Train Split

# %%
#imports 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Modeling

# %%
model = LinearRegression()

# %%
# training the model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
df_model = pd.DataFrame({"true":y_test,"pred":y_pred})
df_model.head()
# Out:
#            true           pred
# 7958   466000.0  411092.069867
# 1321   267500.0  411092.069867
# 16804  607500.0  411092.069867
# 6652   554000.0  577179.547196
# 5613   435000.0  530714.017462

# %% [markdown]
# ## Validation

# %%
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2  = r2_score(y_test,y_pred)

# %%
print("mse",mse)
print("mae",mae)
print("R2" ,r2)
# Out:
# mse 30204878414.632454
# mae 138015.57567317024
# R2 0.26633716219041104

# %%
#r squared value quite low...
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            21597 non-null  int64
#  1   price         21597 non-null  float64
#  2   bedrooms      21597 non-null  int64
#  3   bathrooms     21597 non-null  float64
#  4   floors        21597 non-null  float64
#  5   waterfront    19221 non-null  float64
#  6   condition     21597 non-null  int64
#  7   grade         21597 non-null  int64
#  8   yr_renovated  17755 non-null  float64
#  9   total_sqft    21597 non-null  int64
#  10  age           21597 non-null  int64
# dtypes: float64(5), int64(6)
# memory usage: 1.8 MB

# %%
#maybe we skipped sth...

df_new = pd.read_csv('data/kc_house_data.csv')
df_new.drop(columns= ['date','view','sqft_above','sqft_basement','zipcode','lat','long','sqft_living15','sqft_lot15'],inplace = True)
df_new.head()
# Out:
#            id     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  221900.0         3       1.00         1180      5650     1.0
# 1  6414100192  538000.0         3       2.25         2570      7242     2.0
# 2  5631500400  180000.0         2       1.00          770     10000     1.0
# 3  2487200875  604000.0         4       3.00         1960      5000     1.0
# 4  1954400510  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  condition  grade  yr_built  yr_renovated
# 0         NaN          3      7      1955           0.0
# 1         0.0          3      7      1951        1991.0
# 2         0.0          3      6      1933           NaN
# 3         0.0          5      7      1965           0.0
# 4         0.0          3      8      1987           0.0

# %%
df_new.drop_duplicates(inplace= True)
sns.heatmap(df_new.corr(),cmap="coolwarm",annot=True)
# Out:
# <AxesSubplot:>

# %%
df_new.corr()
# Out:
#                     id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id            1.000000 -0.016779  0.001188   0.005116    -0.012238 -0.131893
# price        -0.016779  1.000000  0.308793   0.525908     0.701918  0.089878
# bedrooms      0.001188  0.308793  1.000000   0.514536     0.578219  0.032462
# bathrooms     0.005116  0.525908  0.514536   1.000000     0.755766  0.088386
# sqft_living  -0.012238  0.701918  0.578219   0.755766     1.000000  0.173454
# sqft_lot     -0.131893  0.089878  0.032462   0.088386     0.173454  1.000000
# floors        0.018522  0.256807  0.177987   0.502565     0.353965 -0.004792
# waterfront   -0.004167  0.276296 -0.002390   0.067288     0.110230  0.023141
# condition    -0.023746  0.036062  0.026473  -0.126454    -0.059444 -0.008845
# grade         0.008138  0.667966  0.356604   0.665834     0.762795  0.114752
# yr_built      0.021507  0.053949  0.155724   0.507157     0.318171  0.052978
# ...

# %%
# top predictors
# sqft_living, grade, bathrooms, bedrooms, floors 
# they exhibit some multi collinearity but lets test them out
 # select most important features
df_transformed_new = df_new[['sqft_living','grade','bathrooms','bedrooms','floors','price']]
df_transformed_new.head()
# Out:
#    sqft_living  grade  bathrooms  bedrooms  floors     price
# 0         1180      7       1.00         3     1.0  221900.0
# 1         2570      7       2.25         3     2.0  538000.0
# 2          770      6       1.00         2     1.0  180000.0
# 3         1960      7       3.00         4     1.0  604000.0
# 4         1680      8       2.00         3     1.0  510000.0

# %%
df_transformed_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21595 entries, 0 to 21596
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   sqft_living  21595 non-null  int64
#  1   grade        21595 non-null  int64
#  2   bathrooms    21595 non-null  float64
#  3   bedrooms     21595 non-null  int64
#  4   floors       21595 non-null  float64
#  5   price        21595 non-null  float64
# dtypes: float64(3), int64(3)
# memory usage: 1.2 MB

# %%
df_transformed_new
# Out:
#        sqft_living  grade  bathrooms  bedrooms  floors     price
# 0             1180      7       1.00         3     1.0  221900.0
# 1             2570      7       2.25         3     2.0  538000.0
# 2              770      6       1.00         2     1.0  180000.0
# 3             1960      7       3.00         4     1.0  604000.0
# 4             1680      8       2.00         3     1.0  510000.0
# ...            ...    ...        ...       ...     ...       ...
# 21592         1530      8       2.50         3     3.0  360000.0
# 21593         2310      8       2.50         4     2.0  400000.0
# 21594         1020      7       0.75         2     2.0  402101.0
# 21595         1600      8       2.50         3     2.0  400000.0
# 21596         1020      7       0.75         2     2.0  325000.0
#
# [21595 rows x 6 columns]

# %%
#lets test out
