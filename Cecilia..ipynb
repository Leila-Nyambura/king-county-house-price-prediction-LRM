# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
# %matplotlib inline

# %% [markdown]
# ### Data Understanding

# %% [markdown]
# Reading the data

# %%
house_data = pd.read_csv('data/kc_house_data.csv')
house_data
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
house_data.head() #display the first 5 rows
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
house_data.tail() #display the last 5 rows
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         NaN   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
house_data.info() #information about the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  float64
#  9   view           21534 non-null  float64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
# ...

# %%
house_data.describe().T
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     19221.0  7.595859e-03  8.682485e-02  0.000000e+00
# view           21534.0  2.338627e-01  7.656862e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# yr_built       21597.0  1.971000e+03  2.937523e+01  1.900000e+03
# ...

# %%
house_data.shape #shape of the dataset ie it has 21597 rows and 21 columns
# Out:
# (21597, 21)

# %%
house_data.columns #columns that are in the dataset
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %% [markdown]
# #### CHECK FOR MISSING VALUES

# %%
house_data.isnull().sum() #check for any missing values
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
house_data['waterfront'].fillna(0, inplace=True) #fill any blanks in waterfront with 0

# %%
house_data['view'].fillna((house_data['view'].mode), inplace=True) #fill any blanks in view with the mode of the values in the view column

# %%
house_data['yr_renovated'].fillna(0, inplace=True) #fill any blanks with 0, to indicate that maybe no renovation took place

# %%
house_data.isna().sum() #check again for any missing values
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
house_data['total_sqft'] = house_data['sqft_living'] + house_data['sqft_lot'] #create a new column total sqft

# %%
house_data.columns #recheck the columns names to confirm the new column has been included
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15', 'total_sqft'],
#       dtype='object')

# %%
house_data.duplicated().sum()
# Out:
# 0

# %%
house_data.drop_duplicates() #drop any duplicates
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront view  ...  sqft_above  sqft_basement  \
# ...

# %%
#drop columns which may not be necessary for modeling/linear regression
columns_to_drop = ['id', 'date', 'sqft_living', 'sqft_lot', 'waterfront', 'view', 
                   'condition', 'sqft_above', 'sqft_basement', 'yr_built', 
                   'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']
house_data2 = house_data.drop(columns=columns_to_drop)
house_data2
# Out:
#           price  bedrooms  bathrooms  floors  grade  yr_renovated  total_sqft
# 0      221900.0         3       1.00     1.0      7           0.0        6830
# 1      538000.0         3       2.25     2.0      7        1991.0        9812
# 2      180000.0         2       1.00     1.0      6           0.0       10770
# 3      604000.0         4       3.00     1.0      7           0.0        6960
# 4      510000.0         3       2.00     1.0      8           0.0        9760
# ...         ...       ...        ...     ...    ...           ...         ...
# 21592  360000.0         3       2.50     3.0      8           0.0        2661
# 21593  400000.0         4       2.50     2.0      8           0.0        8123
# 21594  402101.0         2       0.75     2.0      7           0.0        2370
# 21595  400000.0         3       2.50     2.0      8           0.0        3988
# 21596  325000.0         2       0.75     2.0      7           0.0        2096
#
# [21597 rows x 7 columns]

# %%
sns.pairplot(data=house_data2)

# %%
corr_matrix = house_data2.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
corr_matrix = house_data2.corr()
corr_matrix
# Out:
#                  price  bedrooms  bathrooms    floors     grade  yr_renovated  \
# price         1.000000  0.308787   0.525906  0.256804  0.667951      0.117855
# bedrooms      0.308787  1.000000   0.514508  0.177944  0.356563      0.017900
# bathrooms     0.525906  0.514508   1.000000  0.502582  0.665838      0.047177
# floors        0.256804  0.177944   0.502582  1.000000  0.458794      0.003793
# grade         0.667951  0.356563   0.665838  0.458794  1.000000      0.015623
# yr_renovated  0.117855  0.017900   0.047177  0.003793  0.015623      1.000000
# total_sqft    0.105009  0.045106   0.104700  0.003020  0.131106      0.006086
#
#               total_sqft
# price           0.105009
# bedrooms        0.045106
# bathrooms       0.104700
# floors          0.003020
# grade           0.131106
# yr_renovated    0.006086
# total_sqft      1.000000

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score


features = ['bedrooms', 'bathrooms', 'floors', 'total_sqft','grade']
X = house_data2[features]
y = house_data2['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
lr =LinearRegression()
lr.fit(X_train,y_train)

y_pred = lr.predict(X_test)

print('RMSE:', np.sqrt(mean_squared_error(y_test, y_pred)))
print('R2:', r2_score(y_test,y_pred))
# Out:
# RMSE: 291214.05343560927
# R2: 0.4501311007744898

# %%
model = LinearRegression()


model.fit(X_train, y_train)


y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)


train_rmse = np.sqrt(mean_squared_error(y_train, y_pred_train))
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred_test))
r2 = r2_score(y_test, y_pred_test)

print(f'Train RMSE: {train_rmse:.2f}')
print(f'Test RMSE: {test_rmse:.2f}')
print(f'R-squared: {r2:.2f}')


cv_scores = cross_val_score(model, X, y, cv=5, scoring='r2')
print(f'Cross-validation R-squared: {np.mean(cv_scores):.2f}')
# Out:
# Train RMSE: 257820.24
# Test RMSE: 291214.05
# R-squared: 0.45
# Cross-validation R-squared: 0.47
